# %% [markdown]
# ## LISTAS ## TUPLAS ## DICIONARIOS

# %%
#LISTA permite armazenar varios valores dentro de 1 variavel - cada valor tem 1 posicao dentro da lista e elas tem 1 indice "[,]"

nome = "Guilherme"

# %%
alunos = ["Ana","Carlos","Pedro","Maria"]

print(alunos[1], alunos[3])
# Out:
# Carlos Maria

# %%
alunos.append("João")

# %%
print(alunos)
# Out:
# ['Ana', 'Carlos', 'Pedro', 'Maria', 'João']

# %%
alunos[1] = "Claudio"

# %%
print(alunos)
# Out:
# ['Ana', 'Claudio', 'Pedro', 'Maria', 'João']

# %%
## TUPLAS cada valor delas possui indice e pode ter 1 variavel para varios valores. a tupla nao pode ser alterada depois de criada, a lista pode.

## (,)

# %%
cores = ("Azul","Vermelho","Verde")

# %%
print(cores[1])
# Out:
# Vermelho

# %%
## dicionarios {} chave, valor    pode adicionar novas informacoes

# %%
aluno = {
    "nome": "Professor",
    "idade": 20,
    "cidade": "Florianopolis"
}

# %%
print(aluno["idade"])
# Out:
# 20

# %%
aluno["curso"] = "Analise de dados com Python"

# %%
print(aluno)
# Out:
# {'nome': 'Professor', 'idade': 20, 'cidade': 'Florianopolis', 'curso': 'Analise de dados com Python'}
